# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("datasets/coin_Ethereum.csv")

# %%
df.head()
# Out:
#    SNo      Name Symbol                 Date      High       Low      Open  \
# 0    1  Ethereum    ETH  2015-08-08 23:59:59  2.798810  0.714725  2.793760
# 1    2  Ethereum    ETH  2015-08-09 23:59:59  0.879810  0.629191  0.706136
# 2    3  Ethereum    ETH  2015-08-10 23:59:59  0.729854  0.636546  0.713989
# 3    4  Ethereum    ETH  2015-08-11 23:59:59  1.131410  0.663235  0.708087
# 4    5  Ethereum    ETH  2015-08-12 23:59:59  1.289940  0.883608  1.058750
#
#       Close     Volume     Marketcap
# 0  0.753325   674188.0  4.548689e+07
# 1  0.701897   532170.0  4.239957e+07
# 2  0.708448   405283.0  4.281836e+07
# 3  1.067860  1463100.0  6.456929e+07
# 4  1.217440  2150620.0  7.364501e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2160 non-null   int64
#  1   Name       2160 non-null   object
#  2   Symbol     2160 non-null   object
#  3   Date       2160 non-null   object
#  4   High       2160 non-null   float64
#  5   Low        2160 non-null   float64
#  6   Open       2160 non-null   float64
#  7   Close      2160 non-null   float64
#  8   Volume     2160 non-null   float64
#  9   Marketcap  2160 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 168.9+ KB

# %%
df.describe()
# Out:
#                SNo         High          Low         Open        Close  \
# count  2160.000000  2160.000000  2160.000000  2160.000000  2160.000000
# mean   1080.500000   398.258568   365.592589   382.879899   383.910691
# std     623.682612   628.082281   566.611523   599.719862   601.078766
# min       1.000000     0.482988     0.420897     0.431589     0.434829
# 25%     540.750000    14.265225    13.190950    13.757600    13.819200
# 50%    1080.500000   205.124631   193.302715   198.425096   198.643691
# 75%    1620.250000   396.494561   375.146804   386.264935   386.435272
# max    2160.000000  4362.350542  3785.848603  4174.635873  4168.701049
#
#              Volume     Marketcap
# count  2.160000e+03  2.160000e+03
# mean   7.057058e+09  4.172084e+10
# std    1.064526e+10  6.909184e+10
# min    1.021280e+05  3.221363e+07
# 25%    3.825102e+07  1.135576e+09
# 50%    2.148880e+09  2.070063e+10
# 75%    9.629136e+09  4.231010e+10
# max    8.448291e+10  4.828819e+11

# %%
df.isnull()
# Out:
#         SNo   Name  Symbol   Date   High    Low   Open  Close  Volume  \
# 0     False  False   False  False  False  False  False  False   False
# 1     False  False   False  False  False  False  False  False   False
# 2     False  False   False  False  False  False  False  False   False
# 3     False  False   False  False  False  False  False  False   False
# 4     False  False   False  False  False  False  False  False   False
# ...     ...    ...     ...    ...    ...    ...    ...    ...     ...
# 2155  False  False   False  False  False  False  False  False   False
# 2156  False  False   False  False  False  False  False  False   False
# 2157  False  False   False  False  False  False  False  False   False
# 2158  False  False   False  False  False  False  False  False   False
# 2159  False  False   False  False  False  False  False  False   False
#
#       Marketcap
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# ...

# %%
df.isnull().sum()
# Out:
# SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Name
# Ethereum    2160
# Name: count, dtype: int64

# %%
df['Symbol'].value_counts()
# Out:
# Symbol
# ETH    2160
# Name: count, dtype: int64

# %%
df.index=pd.to_datetime(df.Date)

# %%
df.head()
# Out:
#                      SNo      Name Symbol                 Date      High  \
# Date
# 2015-08-08 23:59:59    1  Ethereum    ETH  2015-08-08 23:59:59  2.798810
# 2015-08-09 23:59:59    2  Ethereum    ETH  2015-08-09 23:59:59  0.879810
# 2015-08-10 23:59:59    3  Ethereum    ETH  2015-08-10 23:59:59  0.729854
# 2015-08-11 23:59:59    4  Ethereum    ETH  2015-08-11 23:59:59  1.131410
# 2015-08-12 23:59:59    5  Ethereum    ETH  2015-08-12 23:59:59  1.289940
#
#                           Low      Open     Close     Volume     Marketcap
# Date
# 2015-08-08 23:59:59  0.714725  2.793760  0.753325   674188.0  4.548689e+07
# 2015-08-09 23:59:59  0.629191  0.706136  0.701897   532170.0  4.239957e+07
# 2015-08-10 23:59:59  0.636546  0.713989  0.708448   405283.0  4.281836e+07
# 2015-08-11 23:59:59  0.663235  0.708087  1.067860  1463100.0  6.456929e+07
# 2015-08-12 23:59:59  0.883608  1.058750  1.217440  2150620.0  7.364501e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2160 entries, 2015-08-08 23:59:59 to 2021-07-06 23:59:59
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2160 non-null   int64
#  1   Name       2160 non-null   object
#  2   Symbol     2160 non-null   object
#  3   Date       2160 non-null   object
#  4   High       2160 non-null   float64
#  5   Low        2160 non-null   float64
#  6   Open       2160 non-null   float64
#  7   Close      2160 non-null   float64
#  8   Volume     2160 non-null   float64
#  9   Marketcap  2160 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 185.6+ KB

# %%
df.drop(['Date','Name','Symbol','Volume','Marketcap','SNo'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                          High       Low      Open     Close
# Date
# 2015-08-08 23:59:59  2.798810  0.714725  2.793760  0.753325
# 2015-08-09 23:59:59  0.879810  0.629191  0.706136  0.701897
# 2015-08-10 23:59:59  0.729854  0.636546  0.713989  0.708448
# 2015-08-11 23:59:59  1.131410  0.663235  0.708087  1.067860
# 2015-08-12 23:59:59  1.289940  0.883608  1.058750  1.217440

# %%
def create_features(df):
    df['dayofweek']=df.index.day_of_week
    df['month']=df.index.month
    df['dayofyear']=df.index.dayofyear

    return df

# %%
df=create_features(df)

# %%
df.head()
# Out:
#                          High       Low      Open     Close  dayofweek  month  \
# Date
# 2015-08-08 23:59:59  2.798810  0.714725  2.793760  0.753325          5      8
# 2015-08-09 23:59:59  0.879810  0.629191  0.706136  0.701897          6      8
# 2015-08-10 23:59:59  0.729854  0.636546  0.713989  0.708448          0      8
# 2015-08-11 23:59:59  1.131410  0.663235  0.708087  1.067860          1      8
# 2015-08-12 23:59:59  1.289940  0.883608  1.058750  1.217440          2      8
#
#                      dayofyear
# Date
# 2015-08-08 23:59:59        220
# 2015-08-09 23:59:59        221
# 2015-08-10 23:59:59        222
# 2015-08-11 23:59:59        223
# 2015-08-12 23:59:59        224

# %%
import seaborn as sns

# %%
sns.displot(data= df,x=df.index,y='Close')

# %%
df['Close'].loc[(df.index<'01-01-2020')].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].loc[(df.index>'01-01-2020')].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.tail()
# Out:
#                             High          Low         Open        Close  \
# Date
# 2021-07-02 23:59:59  2155.596496  2021.824808  2109.892677  2150.040364
# 2021-07-03 23:59:59  2237.567155  2117.590013  2150.835025  2226.114282
# 2021-07-04 23:59:59  2384.286857  2190.837703  2226.550382  2321.724112
# 2021-07-05 23:59:59  2321.922836  2163.041394  2321.922836  2198.582464
# 2021-07-06 23:59:59  2346.294874  2197.919385  2197.919385  2324.679449
#
#                      dayofweek  month  dayofyear
# Date
# 2021-07-02 23:59:59          4      7        183
# 2021-07-03 23:59:59          5      7        184
# 2021-07-04 23:59:59          6      7        185
# 2021-07-05 23:59:59          0      7        186
# 2021-07-06 23:59:59          1      7        187

# %%
new_df = pd.read_csv("Ethereum Historical Data.csv")

# %%
new_df.head()
# Out:
#          Date    Price     Open     High      Low     Vol. Change %
# 0    3/5/2026  2311.34  2317.00  2317.03  2297.65  108.81K   -0.24%
# 1    2/5/2026  2316.96  2296.12  2338.93  2293.01   99.04K    0.93%
# 2    1/5/2026  2295.59  2257.41  2324.52  2257.41  224.35K    1.70%
# 3  30-04-2026  2257.19  2252.89  2278.89  2232.17  203.04K    0.19%
# 4  29-04-2026  2252.84  2289.56  2346.26  2221.20  418.41K   -1.61%

# %%
new_df=new_df.iloc[::-1].reset_index(drop = True)

# %%
new_df.head()
# Out:
#         Date    Price     Open     High      Low     Vol. Change %
# 0   7/7/2021  2316.57  2322.74  2402.68  2296.43    1.32M   -0.26%
# 1   8/7/2021  2120.22  2316.21  2322.47  2095.92    1.82M   -8.48%
# 2   9/7/2021  2145.89  2120.05  2185.62  2066.09    1.42M    1.21%
# 3  10/7/2021  2111.12  2146.15  2191.30  2078.43  929.32K   -1.62%
# 4  11/7/2021  2139.35  2110.90  2173.34  2081.62  724.84K    1.34%

# %%
new_df.index=pd.to_datetime(new_df['Date'], format='mixed', dayfirst=True)

# %%
new_df.head()
# Out:
#                  Date    Price     Open     High      Low     Vol. Change %
# Date
# 2021-07-07   7/7/2021  2316.57  2322.74  2402.68  2296.43    1.32M   -0.26%
# 2021-07-08   8/7/2021  2120.22  2316.21  2322.47  2095.92    1.82M   -8.48%
# 2021-07-09   9/7/2021  2145.89  2120.05  2185.62  2066.09    1.42M    1.21%
# 2021-07-10  10/7/2021  2111.12  2146.15  2191.30  2078.43  929.32K   -1.62%
# 2021-07-11  11/7/2021  2139.35  2110.90  2173.34  2081.62  724.84K    1.34%

# %%
new_df.rename(columns = {'Price' : 'Close'},inplace =True)

# %%
new_df.head()
# Out:
#                  Date    Close     Open     High      Low     Vol. Change %
# Date
# 2021-07-07   7/7/2021  2316.57  2322.74  2402.68  2296.43    1.32M   -0.26%
# 2021-07-08   8/7/2021  2120.22  2316.21  2322.47  2095.92    1.82M   -8.48%
# 2021-07-09   9/7/2021  2145.89  2120.05  2185.62  2066.09    1.42M    1.21%
# 2021-07-10  10/7/2021  2111.12  2146.15  2191.30  2078.43  929.32K   -1.62%
# 2021-07-11  11/7/2021  2139.35  2110.90  2173.34  2081.62  724.84K    1.34%

# %%
new_df.drop(['Date','Vol.','Change %'],axis=1,inplace=True)

# %%
new_df.head()
# Out:
#               Close     Open     High      Low
# Date
# 2021-07-07  2316.57  2322.74  2402.68  2296.43
# 2021-07-08  2120.22  2316.21  2322.47  2095.92
# 2021-07-09  2145.89  2120.05  2185.62  2066.09
# 2021-07-10  2111.12  2146.15  2191.30  2078.43
# 2021-07-11  2139.35  2110.90  2173.34  2081.62

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1762 entries, 2021-07-07 to 2026-05-03
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1762 non-null   float64
#  1   Open    1762 non-null   float64
#  2   High    1762 non-null   float64
#  3   Low     1762 non-null   float64
# dtypes: float64(4)
# memory usage: 68.8 KB

# %%
new_df.isnull().sum()
# Out:
# Close    0
# Open     0
# High     0
# Low      0
# dtype: int64

# %%
new_df= create_features(new_df)

# %%
new_df.head()
# Out:
#               Close     Open     High      Low  dayofweek  month  dayofyear
# Date
# 2021-07-07  2316.57  2322.74  2402.68  2296.43          2      7        188
# 2021-07-08  2120.22  2316.21  2322.47  2095.92          3      7        189
# 2021-07-09  2145.89  2120.05  2185.62  2066.09          4      7        190
# 2021-07-10  2111.12  2146.15  2191.30  2078.43          5      7        191
# 2021-07-11  2139.35  2110.90  2173.34  2081.62          6      7        192

# %%
features = ['High','Low','Open','dayofweek','month','dayofyear' ]
target='Close'

# %%
x_train=df[features]
y_train=df[target]

x_test=new_df[features]
y_test=new_df[target]

# %%
x_train
# Out:
#                             High          Low         Open  dayofweek  month  \
# Date
# 2015-08-08 23:59:59     2.798810     0.714725     2.793760          5      8
# 2015-08-09 23:59:59     0.879810     0.629191     0.706136          6      8
# 2015-08-10 23:59:59     0.729854     0.636546     0.713989          0      8
# 2015-08-11 23:59:59     1.131410     0.663235     0.708087          1      8
# 2015-08-12 23:59:59     1.289940     0.883608     1.058750          2      8
# ...                          ...          ...          ...        ...    ...
# 2021-07-02 23:59:59  2155.596496  2021.824808  2109.892677          4      7
# 2021-07-03 23:59:59  2237.567155  2117.590013  2150.835025          5      7
# 2021-07-04 23:59:59  2384.286857  2190.837703  2226.550382          6      7
# 2021-07-05 23:59:59  2321.922836  2163.041394  2321.922836          0      7
# 2021-07-06 23:59:59  2346.294874  2197.919385  2197.919385          1      7
#
#                      dayofyear
# Date
# ...

# %%
import xgboost as xgb

# %%
xgbr=xgb.XGBRFRegressor()

# %%
xgbr.fit(x_train,y_train)
# Out:
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, feature_weights=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squarederror',
#                random_state=None, ...)

# %%
xgbr.score(x_train,y_train)
# Out:
# 0.999120414540206

# %%
xgbr.score(x_test,y_test)
# Out:
# 0.9431897995102033

# %%
predictions = xgbr.predict(x_test)

# %%
predictions
# Out:
# array([2372.7825, 2270.786 , 2140.3772, ..., 2327.3435, 2327.6055,
#        2224.14  ], shape=(1762,), dtype=float32)

# %%
xgbr=xgb.XGBRegressor(colsample_bytree=0.7,learning_rate=0.01,max_depth=3,n_estimators=500,objective='reg:squarederror')

# %%
xgbr.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xgbr.score(x_train,y_train)
# Out:
# 0.9986591938501193

# %%
xgbr.score(x_test,y_test)
# Out:
# 0.9484216063718551

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predictions)
mae
# Out:
# 123.57878927033823

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,predictions ))
print("RMSE:", rmse)
from sklearn.metrics import r2_score
r2 = r2_score(y_test,predictions)
print("R2 Score:", r2)
mae_percent = (mae / y_test.mean()) * 100
print("MAE %:", mae_percent)
# Out:
# RMSE: 213.60434150669414
# R2 Score: 0.9431897995102033
# MAE %: 4.805977590947618

# %%
fi=pd.DataFrame(data=xgbr.feature_importances_,
                index=xgbr.get_booster().feature_names,
                columns=['impotance'])
fi.sort_values('impotance').plot(kind='barh',title='Feature Importance')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8,5))
sns.heatmap(extended_df.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Matrix")
plt.show()

# %%
sns.histplot(extended_df['Close'], kde=True)
plt.title("Distribution of Closing Prices")
# Out:
# Text(0.5, 1.0, 'Distribution of Closing Prices')

# %%
plt.figure(figsize=(10,5))
plt.plot(df, label='Train')
plt.plot(new_df, label='Test')
plt.legend()
plt.title("Train-Test Split")
plt.show()

# %%
extended_df = pd.concat([df, new_df])
extended_df
# Out:
#                             High          Low         Open        Close  \
# Date
# 2015-08-08 23:59:59     2.798810     0.714725     2.793760     0.753325
# 2015-08-09 23:59:59     0.879810     0.629191     0.706136     0.701897
# 2015-08-10 23:59:59     0.729854     0.636546     0.713989     0.708448
# 2015-08-11 23:59:59     1.131410     0.663235     0.708087     1.067860
# 2015-08-12 23:59:59     1.289940     0.883608     1.058750     1.217440
# ...                          ...          ...          ...          ...
# 2026-04-29 00:00:00  2346.260000  2221.200000  2289.560000  2252.840000
# 2026-04-30 00:00:00  2278.890000  2232.170000  2252.890000  2257.190000
# 2026-05-01 00:00:00  2324.520000  2257.410000  2257.410000  2295.590000
# 2026-05-02 00:00:00  2338.930000  2293.010000  2296.120000  2316.960000
# 2026-05-03 00:00:00  2317.030000  2297.650000  2317.000000  2311.340000
#
#                      dayofweek  month  dayofyear
# Date
# ...

# %%
new_df['predictions']=xgbr.predict(x_test)
extended_df=extended_df.merge(new_df[['predictions']],how='left',left_index=True,right_index=True)

# %%
ax=extended_df['Close'].loc[extended_df.index>'01-01-2021'].plot(figsize=(15,5))
extended_df['predictions'].plot(ax=ax,style='.')
plt.legend(['Actual Values','Predictions'])
ax.set_title('Entire dataset against predictions')
plt.show()

# %%
import pickle
filename="predict_eth.pkl"
pickle.dump(xgbr,open(filename,"wb")
# Out:
#   Cell In[62], line 3
#     pickle.dump(xgbr,open(filename,"wb")
#                                         ^
# _IncompleteInputError: incomplete input
